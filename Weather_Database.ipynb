# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
#Import The Google API key.
from config import weather_api_key1

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key1
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=30a8c9326714af2a3dd1d9aed82ffcfc

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        print(city_weather)
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 79.57, 'feels_like': 81.23, 'temp_min': 79.57, 'temp_max': 79.57, 'pressure': 1016, 'humidity': 66, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 8.19, 'deg': 22}, 'clouds': {'all': 16}, 'dt': 1610754611, 'sys': {'country': 'PF', 'sunrise': 1610720853, 'sunset': 1610769056}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 2 of Set 1 | kintinku
# {'coord': {'lon': 35.2333, 'lat': -5.8833}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 66.92, 'feels_like': 71.46, 'temp_min': 66.92, 'temp_max': 66.92, 'pressure': 1012, 'humidity': 93, 'sea_level': 1012, 'grnd_level': 917}, 'visibility': 10000, 'wind': {'speed': 1.21, 'deg': 343}, 'rain': {'1h': 1.27}, 'clouds': {'all': 12}, 'dt': 1610755002, 'sys': {'country': 'TZ', 'sunrise': 1610768160, 'sunset': 1610812873}, 'timezone': 10800, 'id': 157247, 'name': 'Kintinku', 'cod': 200}
# Processing Record 3 of Set 1 | bozeman
# {'coord': {'lon': -111.0386, 'lat': 45.6796}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 34.27, 'feels_like': 28.4, 'temp_min': 33.01, 'temp_max': 35.6, 'pressure': 1022, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 1.23, 'deg': 276}, 'clouds': {'all': 90}, 'dt': 1610755002, 'sys': {'type': 1, 'id': 3546, 'country': 'US', 'sunrise': 1610722842, 'sunset': 1610755577}, 'timezone': -25200, 'id': 5641727, 'name': 'Bozeman', 'cod': 200}
# Processing Record 4 of Set 1 | esqueda
# {'coord': {'lon': -109.5833, 'lat': 30.7167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 64.72, 'feels_like': 56.59, 'temp_min': 64.72, 'temp_max': 64.72, 'pressure': 1016, 'humidity': 25, 'sea_level': 1016, 'grnd_level': 882}, 'visibility': 10000, 'wind': {'speed': 7.16, 'deg': 23}, 'clouds': {'all': 0}, 'dt': 1610755002, 'sys': {'country': 'MX', 'sunrise': 1610720174, 'sunset': 1610757546}, 'timezone': -25200, 'id': 4006532, 'name': 'Esqueda', 'cod': 200}
# Processing Record 5 of Set 1 | georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 76.44, 'feels_like': 83.32, 'temp_min': 75, 'temp_max': 78.01, 'pressure': 1008, 'humidity': 94}, 'visibility': 8000, 'wind': {'speed': 5.75, 'deg': 60}, 'clouds': {'all': 20}, 'dt': 1610754643, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1610753573, 'sunset': 1610796204}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# Processing Record 6 of Set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 35.24, 'feels_like': 26.04, 'temp_min': 33.8, 'temp_max': 36, 'pressure': 1003, 'humidity': 93}, 'visibility': 8047, 'wind': {'speed': 10.36, 'deg': 160}, 'snow': {'1h': 1.4}, 'clouds': {'all': 90}, 'dt': 1610754607, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1610714551, 'sunset': 1610748599}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 7 of Set 1 | kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.41, 'feels_like': 77.81, 'temp_min': 75, 'temp_max': 80.6, 'pressure': 1017, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 160}, 'rain': {'1h': 0.51}, 'clouds': {'all': 1}, 'dt': 1610754614, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1610731117, 'sunset': 1610770483}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 8 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 57.24, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1011, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 340}, 'clouds': {'all': 40}, 'dt': 1610754608, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1610698968, 'sunset': 1610758931}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 9 of Set 1 | nikki
# {'coord': {'lon': 3.2108, 'lat': 9.9401}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 70.48, 'feels_like': 63.57, 'temp_min': 70.48, 'temp_max': 70.48, 'pressure': 1010, 'humidity': 21, 'sea_level': 1010, 'grnd_level': 964}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 21}, 'clouds': {'all': 0}, 'dt': 1610755003, 'sys': {'country': 'BJ', 'sunrise': 1610777308, 'sunset': 1610819100}, 'timezone': 3600, 'id': 2392505, 'name': 'Nikki', 'cod': 200}
# Processing Record 10 of Set 1 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 73, 'feels_like': 71.08, 'temp_min': 73, 'temp_max': 73, 'pressure': 1007, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 179, 'gust': 17}, 'clouds': {'all': 14}, 'dt': 1610754539, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1610730843, 'sunset': 1610786033}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 11 of Set 1 | nadym
# {'coord': {'lon': 72.5167, 'lat': 65.5333}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 0.36, 'feels_like': -9.92, 'temp_min': 0.36, 'temp_max': 0.36, 'pressure': 1015, 'humidity': 93, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 174, 'wind': {'speed': 6.98, 'deg': 127}, 'snow': {'1h': 0.24}, 'clouds': {'all': 100}, 'dt': 1610755003, 'sys': {'country': 'RU', 'sunrise': 1610772792, 'sunset': 1610790341}, 'timezone': 18000, 'id': 1498087, 'name': 'Nadym', 'cod': 200}
# Processing Record 12 of Set 1 | tuatapere
# {'coord': {'lon': 167.6833, 'lat': -46.1333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 73, 'feels_like': 71.08, 'temp_min': 73, 'temp_max': 73, 'pressure': 1007, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 179, 'gust': 17}, 'clouds': {'all': 25}, 'dt': 1610754537, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1610731139, 'sunset': 1610786303}, 'timezone': 46800, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# Processing Record 13 of Set 1 | dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -32.31, 'feels_like': -42.29, 'temp_min': -32.31, 'temp_max': -32.31, 'pressure': 1033, 'humidity': 79, 'sea_level': 1033, 'grnd_level': 1027}, 'visibility': 10000, 'wind': {'speed': 5.17, 'deg': 128}, 'clouds': {'all': 76}, 'dt': 1610754611, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 14 of Set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 64.87, 'feels_like': 64.08, 'temp_min': 63, 'temp_max': 66.99, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 320}, 'rain': {'1h': 0.22}, 'clouds': {'all': 20}, 'dt': 1610754381, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1610769113, 'sunset': 1610819992}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 15 of Set 1 | tsihombe
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 16 of Set 1 | kodiak
# {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.6, 'feels_like': 30.11, 'temp_min': 35.6, 'temp_max': 35.6, 'pressure': 996, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 290}, 'clouds': {'all': 90}, 'dt': 1610754366, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1610736055, 'sunset': 1610762226}, 'timezone': -32400, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 17 of Set 1 | sambava
# {'coord': {'lon': 50.1667, 'lat': -14.2667}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.99, 'feels_like': 83.26, 'temp_min': 77.99, 'temp_max': 77.99, 'pressure': 1009, 'humidity': 87, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 7.81, 'deg': 199}, 'rain': {'1h': 0.4}, 'clouds': {'all': 63}, 'dt': 1610754927, 'sys': {'country': 'MG', 'sunrise': 1610763772, 'sunset': 1610810092}, 'timezone': 10800, 'id': 1056899, 'name': 'Sambava', 'cod': 200}
# Processing Record 18 of Set 1 | ugoofaaru
# {'coord': {'lon': 73, 'lat': 5.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.92, 'feels_like': 82.69, 'temp_min': 80.92, 'temp_max': 80.92, 'pressure': 1007, 'humidity': 71, 'sea_level': 1007, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 10.98, 'deg': 184}, 'clouds': {'all': 54}, 'dt': 1610754987, 'sys': {'country': 'MV', 'sunrise': 1610760158, 'sunset': 1610802743}, 'timezone': 18000, 'id': 1337619, 'name': 'Ugoofaaru', 'cod': 200}
# Processing Record 19 of Set 1 | rangapara
# {'coord': {'lon': 92.65, 'lat': 26.8167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 57.52, 'feels_like': 56.3, 'temp_min': 57.52, 'temp_max': 57.52, 'pressure': 1012, 'humidity': 77, 'sea_level': 1012, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 2.51, 'deg': 50}, 'clouds': {'all': 18}, 'dt': 1610755004, 'sys': {'country': 'IN', 'sunrise': 1610757568, 'sunset': 1610795899}, 'timezone': 19800, 'id': 1258501, 'name': 'Rangāpāra', 'cod': 200}
# Processing Record 20 of Set 1 | paamiut
# {'coord': {'lon': -49.6678, 'lat': 61.994}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 23.68, 'feels_like': 11.26, 'temp_min': 23.68, 'temp_max': 23.68, 'pressure': 1007, 'humidity': 94, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 13.58, 'deg': 139}, 'clouds': {'all': 81}, 'dt': 1610754638, 'sys': {'country': 'GL', 'sunrise': 1610713365, 'sunset': 1610735589}, 'timezone': -10800, 'id': 3421193, 'name': 'Paamiut', 'cod': 200}
# Processing Record 21 of Set 1 | grand river south east
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 22 of Set 1 | port augusta
# {'coord': {'lon': 137.7667, 'lat': -32.5}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.89, 'feels_like': 52.54, 'temp_min': 62.6, 'temp_max': 63, 'pressure': 1021, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 150}, 'clouds': {'all': 90}, 'dt': 1610755004, 'sys': {'type': 1, 'id': 9613, 'country': 'AU', 'sunrise': 1610740650, 'sunset': 1610791156}, 'timezone': 37800, 'id': 2063056, 'name': 'Port Augusta', 'cod': 200}
# Processing Record 23 of Set 1 | lompoc
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.04, 'feels_like': 59.38, 'temp_min': 68, 'temp_max': 69.8, 'pressure': 1019, 'humidity': 46}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 270}, 'clouds': {'all': 66}, 'dt': 1610754423, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1610723298, 'sunset': 1610759644}, 'timezone': -28800, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# Processing Record 24 of Set 1 | egvekinot
# {'coord': {'lon': -179.1667, 'lat': 66.3167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -7.69, 'feels_like': -23.64, 'temp_min': -7.69, 'temp_max': -7.69, 'pressure': 1013, 'humidity': 90, 'sea_level': 1013, 'grnd_level': 956}, 'visibility': 6391, 'wind': {'speed': 16.53, 'deg': 11}, 'clouds': {'all': 100}, 'dt': 1610754675, 'sys': {'country': 'RU', 'sunrise': 1610833785, 'sunset': 1610850185}, 'timezone': 43200, 'id': 4031742, 'name': 'Egvekinot', 'cod': 200}
# Processing Record 25 of Set 1 | vaitupu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 26 of Set 1 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 15.8, 'feels_like': 5.76, 'temp_min': 15.8, 'temp_max': 15.8, 'pressure': 1010, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 120}, 'clouds': {'all': 75}, 'dt': 1610754620, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 27 of Set 1 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.99, 'feels_like': 81.93, 'temp_min': 75.99, 'temp_max': 75.99, 'pressure': 1009, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 238, 'gust': 8.01}, 'clouds': {'all': 93}, 'dt': 1610754606, 'sys': {'type': 3, 'id': 2005652, 'country': 'EC', 'sunrise': 1610712362, 'sunset': 1610756125}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 28 of Set 1 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.19, 'feels_like': 69.55, 'temp_min': 71.01, 'temp_max': 75.2, 'pressure': 1006, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 20}, 'clouds': {'all': 0}, 'dt': 1610754625, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1610700285, 'sunset': 1610752457}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 29 of Set 1 | ahipara
# {'coord': {'lon': 173.1667, 'lat': -35.1667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 72.01, 'feels_like': 70.03, 'temp_min': 72.01, 'temp_max': 72.01, 'pressure': 1013, 'humidity': 54, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 5.95, 'deg': 245}, 'clouds': {'all': 43}, 'dt': 1610754627, 'sys': {'country': 'NZ', 'sunrise': 1610731770, 'sunset': 1610783040}, 'timezone': 46800, 'id': 2194098, 'name': 'Ahipara', 'cod': 200}
# Processing Record 30 of Set 1 | marang
# {'coord': {'lon': 103.2059, 'lat': 5.2056}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 73.2, 'feels_like': 80.24, 'temp_min': 73, 'temp_max': 73.4, 'pressure': 1009, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1610755005, 'sys': {'type': 1, 'id': 9440, 'country': 'MY', 'sunrise': 1610752865, 'sunset': 1610795534}, 'timezone': 28800, 'id': 1734715, 'name': 'Marang', 'cod': 200}
# Processing Record 31 of Set 1 | oyama
# {'coord': {'lon': 139.8, 'lat': 36.3}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 42.08, 'feels_like': 37.96, 'temp_min': 37.4, 'temp_max': 46, 'pressure': 1012, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 190}, 'clouds': {'all': 40}, 'dt': 1610755005, 'sys': {'type': 1, 'id': 7957, 'country': 'JP', 'sunrise': 1610747464, 'sunset': 1610783366}, 'timezone': 32400, 'id': 1853483, 'name': 'Oyama', 'cod': 200}
# Processing Record 32 of Set 1 | port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 66, 'feels_like': 68.76, 'temp_min': 66, 'temp_max': 66, 'pressure': 1004, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 312, 'gust': 8.01}, 'clouds': {'all': 40}, 'dt': 1610754422, 'sys': {'type': 3, 'id': 2011314, 'country': 'ZA', 'sunrise': 1610767126, 'sunset': 1610817913}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 33 of Set 1 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73, 'feels_like': 71.08, 'temp_min': 73, 'temp_max': 73, 'pressure': 1007, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 8.99, 'deg': 179, 'gust': 17}, 'clouds': {'all': 89}, 'dt': 1610754608, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1610730881, 'sunset': 1610786250}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 34 of Set 1 | avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 89.91, 'temp_min': 86, 'temp_max': 86, 'pressure': 1014, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 60}, 'clouds': {'all': 33}, 'dt': 1610754609, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1610727021, 'sunset': 1610774797}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Processing Record 35 of Set 1 | woensdrecht
# {'coord': {'lon': 4.337, 'lat': 51.4163}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 34.43, 'feels_like': 28.72, 'temp_min': 33.8, 'temp_max': 36, 'pressure': 1030, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 240}, 'clouds': {'all': 90}, 'dt': 1610755005, 'sys': {'type': 1, 'id': 1560, 'country': 'NL', 'sunrise': 1610782809, 'sunset': 1610813058}, 'timezone': 3600, 'id': 2744256, 'name': 'Gemeente Woensdrecht', 'cod': 200}
# Processing Record 36 of Set 1 | thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 6.8, 'feels_like': -2.04, 'temp_min': 6.8, 'temp_max': 6.8, 'pressure': 1018, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 220}, 'clouds': {'all': 75}, 'dt': 1610754605, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1610722241, 'sunset': 1610749849}, 'timezone': -21600, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# Processing Record 37 of Set 1 | yulara
# {'coord': {'lon': 130.9889, 'lat': -25.2406}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 62.11, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1016, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 140}, 'clouds': {'all': 90}, 'dt': 1610754612, 'sys': {'type': 1, 'id': 9487, 'country': 'AU', 'sunrise': 1610743192, 'sunset': 1610791868}, 'timezone': 34200, 'id': 6355222, 'name': 'Yulara', 'cod': 200}
# Processing Record 38 of Set 1 | spring hill
# {'coord': {'lon': -82.5255, 'lat': 28.4769}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.67, 'feels_like': 57.04, 'temp_min': 59, 'temp_max': 60.8, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 300}, 'clouds': {'all': 90}, 'dt': 1610755006, 'sys': {'type': 1, 'id': 3457, 'country': 'US', 'sunrise': 1610713408, 'sunset': 1610751322}, 'timezone': -18000, 'id': 4173838, 'name': 'Spring Hill', 'cod': 200}
# Processing Record 39 of Set 1 | evans
# {'coord': {'lon': -82.1307, 'lat': 33.5337}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 47.39, 'feels_like': 43.66, 'temp_min': 44.01, 'temp_max': 51.8, 'pressure': 1006, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 120}, 'clouds': {'all': 40}, 'dt': 1610754868, 'sys': {'type': 1, 'id': 3848, 'country': 'US', 'sunrise': 1610713951, 'sunset': 1610750589}, 'timezone': -18000, 'id': 4193699, 'name': 'Evans', 'cod': 200}
# Processing Record 40 of Set 1 | tazmalt
# {'coord': {'lon': 4.3989, 'lat': 36.3868}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 41.94, 'feels_like': 37.08, 'temp_min': 41.94, 'temp_max': 41.94, 'pressure': 1022, 'humidity': 78, 'sea_level': 1022, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 3.29, 'deg': 262}, 'clouds': {'all': 6}, 'dt': 1610755006, 'sys': {'country': 'DZ', 'sunrise': 1610779965, 'sunset': 1610815872}, 'timezone': 3600, 'id': 2477537, 'name': 'Tazmalt', 'cod': 200}
# Processing Record 41 of Set 1 | ketchikan
# {'coord': {'lon': -131.6461, 'lat': 55.3422}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 42.8, 'feels_like': 37.83, 'temp_min': 42.8, 'temp_max': 42.8, 'pressure': 1018, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 140}, 'rain': {'1h': 0.51}, 'clouds': {'all': 90}, 'dt': 1610754371, 'sys': {'type': 1, 'id': 7741, 'country': 'US', 'sunrise': 1610730212, 'sunset': 1610758101}, 'timezone': -32400, 'id': 5554428, 'name': 'Ketchikan', 'cod': 200}
# Processing Record 42 of Set 1 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 36.93, 'feels_like': 28.27, 'temp_min': 33.01, 'temp_max': 39, 'pressure': 1011, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 8.48, 'deg': 128}, 'clouds': {'all': 100}, 'dt': 1610754592, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1610713374, 'sunset': 1610747246}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 43 of Set 1 | cabo san lucas
# {'coord': {'lon': -109.9124, 'lat': 22.8909}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 76.73, 'feels_like': 67.33, 'temp_min': 75, 'temp_max': 78.01, 'pressure': 1014, 'humidity': 23}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 230}, 'clouds': {'all': 1}, 'dt': 1610754365, 'sys': {'type': 1, 'id': 7151, 'country': 'MX', 'sunrise': 1610719347, 'sunset': 1610758532}, 'timezone': -25200, 'id': 3985710, 'name': 'Cabo San Lucas', 'cod': 200}
# Processing Record 44 of Set 1 | verkhoyansk
# {'coord': {'lon': 133.385, 'lat': 67.5447}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -32.13, 'feels_like': -39.91, 'temp_min': -32.13, 'temp_max': -32.13, 'pressure': 1027, 'humidity': 81, 'sea_level': 1027, 'grnd_level': 1008}, 'visibility': 540, 'wind': {'speed': 1.28, 'deg': 87}, 'clouds': {'all': 100}, 'dt': 1610755006, 'sys': {'country': 'RU', 'sunrise': 1610760340, 'sunset': 1610773570}, 'timezone': 36000, 'id': 2013465, 'name': 'Verkhoyansk', 'cod': 200}
# Processing Record 45 of Set 1 | padang
# {'coord': {'lon': 100.3543, 'lat': -0.9492}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.78, 'feels_like': 78.33, 'temp_min': 75.78, 'temp_max': 75.78, 'pressure': 1010, 'humidity': 66, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.8, 'deg': 66}, 'clouds': {'all': 56}, 'dt': 1610754641, 'sys': {'country': 'ID', 'sunrise': 1610752983, 'sunset': 1610796785}, 'timezone': 25200, 'id': 1633419, 'name': 'Padang', 'cod': 200}
# Processing Record 46 of Set 1 | atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.56, 'feels_like': 78.12, 'temp_min': 77.56, 'temp_max': 77.56, 'pressure': 1011, 'humidity': 77, 'sea_level': 1011, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 12.35, 'deg': 74}, 'rain': {'1h': 0.14}, 'clouds': {'all': 13}, 'dt': 1610754586, 'sys': {'country': 'PF', 'sunrise': 1610723200, 'sunset': 1610768660}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 47 of Set 1 | grand gaube
# {'coord': {'lon': 57.6608, 'lat': -20.0064}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.01, 'feels_like': 86.83, 'temp_min': 80.01, 'temp_max': 80.01, 'pressure': 1010, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 103, 'gust': 13}, 'clouds': {'all': 1}, 'dt': 1610755007, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1610761383, 'sunset': 1610808883}, 'timezone': 14400, 'id': 934479, 'name': 'Grand Gaube', 'cod': 200}
# Processing Record 48 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 55.2, 'feels_like': 47.57, 'temp_min': 55, 'temp_max': 55.4, 'pressure': 1012, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1610754590, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1610700145, 'sunset': 1610759011}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 49 of Set 1 | kasongo-lunda
# {'coord': {'lon': 16.8167, 'lat': -6.4667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.94, 'feels_like': 75.96, 'temp_min': 69.94, 'temp_max': 69.94, 'pressure': 1011, 'humidity': 92, 'sea_level': 1011, 'grnd_level': 957}, 'visibility': 10000, 'wind': {'speed': 0.72, 'deg': 255}, 'clouds': {'all': 100}, 'dt': 1610755007, 'sys': {'country': 'CD', 'sunrise': 1610772527, 'sunset': 1610817348}, 'timezone': 3600, 'id': 2315026, 'name': 'Kasongo-Lunda', 'cod': 200}
# Processing Record 50 of Set 1 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 55.47, 'temp_min': 59, 'temp_max': 59, 'pressure': 1009, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 9.62, 'deg': 311}, 'clouds': {'all': 1}, 'dt': 1610754589, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1610768847, 'sunset': 1610819867}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 1 of Set 2 | airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 64.53, 'feels_like': 68.95, 'temp_min': 64.53, 'temp_max': 64.53, 'pressure': 1006, 'humidity': 100, 'sea_level': 1006, 'grnd_level': 853}, 'visibility': 10000, 'wind': {'speed': 1.16, 'deg': 315}, 'rain': {'1h': 0.28}, 'clouds': {'all': 100}, 'dt': 1610754616, 'sys': {'country': 'TL', 'sunrise': 1610746225, 'sunset': 1610791514}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 2 of Set 2 | zaria
# {'coord': {'lon': 7.7227, 'lat': 11.1113}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.11, 'feels_like': 55.74, 'temp_min': 64.11, 'temp_max': 64.11, 'pressure': 1012, 'humidity': 27, 'sea_level': 1012, 'grnd_level': 938}, 'visibility': 10000, 'wind': {'speed': 7.87, 'deg': 65}, 'clouds': {'all': 0}, 'dt': 1610755007, 'sys': {'country': 'NG', 'sunrise': 1610776335, 'sunset': 1610817907}, 'timezone': 3600, 'id': 2317765, 'name': 'Zaria', 'cod': 200}
# Processing Record 3 of Set 2 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 64.92, 'feels_like': 62.44, 'temp_min': 63, 'temp_max': 66, 'pressure': 1022, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 78, 'gust': 14}, 'clouds': {'all': 0}, 'dt': 1610754539, 'sys': {'type': 3, 'id': 2020551, 'country': 'AU', 'sunrise': 1610745878, 'sunset': 1610796699}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 4 of Set 2 | severo-kurilsk
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 28.45, 'feels_like': 18.01, 'temp_min': 28.45, 'temp_max': 28.45, 'pressure': 1011, 'humidity': 95, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 6944, 'wind': {'speed': 11.05, 'deg': 198}, 'snow': {'1h': 0.56}, 'clouds': {'all': 100}, 'dt': 1610754596, 'sys': {'country': 'RU', 'sunrise': 1610746216, 'sunset': 1610776776}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 5 of Set 2 | hithadhoo
# {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.23, 'feels_like': 82.44, 'temp_min': 81.23, 'temp_max': 81.23, 'pressure': 1008, 'humidity': 77, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 14.54, 'deg': 274}, 'clouds': {'all': 88}, 'dt': 1610754616, 'sys': {'country': 'MV', 'sunrise': 1610759562, 'sunset': 1610803299}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 6 of Set 2 | sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 7 of Set 2 | russkaya polyana
# {'coord': {'lon': 31.9201, 'lat': 49.417}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 12.09, 'feels_like': -0.81, 'temp_min': 12.09, 'temp_max': 12.09, 'pressure': 1014, 'humidity': 91, 'sea_level': 1014, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 288}, 'clouds': {'all': 79}, 'dt': 1610755008, 'sys': {'country': 'UA', 'sunrise': 1610775706, 'sunset': 1610806918}, 'timezone': 7200, 'id': 695104, 'name': 'Ruska Poliana', 'cod': 200}
# Processing Record 8 of Set 2 | pachino
# {'coord': {'lon': 15.0907, 'lat': 36.7186}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 50, 'feels_like': 48.49, 'temp_min': 50, 'temp_max': 50, 'pressure': 1007, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 0, 'gust': 5.99}, 'clouds': {'all': 2}, 'dt': 1610755008, 'sys': {'type': 3, 'id': 2028557, 'country': 'IT', 'sunrise': 1610777448, 'sunset': 1610813257}, 'timezone': 3600, 'id': 6539213, 'name': 'Pachino', 'cod': 200}
# Processing Record 9 of Set 2 | yellowknife
# {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 10.4, 'feels_like': -3.24, 'temp_min': 10.4, 'temp_max': 10.4, 'pressure': 1005, 'humidity': 92}, 'visibility': 1609, 'wind': {'speed': 13.8, 'deg': 70, 'gust': 19.57}, 'snow': {'1h': 0.31}, 'clouds': {'all': 90}, 'dt': 1610754605, 'sys': {'type': 1, 'id': 1007, 'country': 'CA', 'sunrise': 1610729133, 'sunset': 1610750877}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 10 of Set 2 | pangnirtung
# {'coord': {'lon': -65.7125, 'lat': 66.1451}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 10.4, 'feels_like': -4.25, 'temp_min': 10.4, 'temp_max': 10.4, 'pressure': 1006, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 140, 'gust': 23.02}, 'clouds': {'all': 90}, 'dt': 1610754616, 'sys': {'type': 1, 'id': 968, 'country': 'CA', 'sunrise': 1610720241, 'sunset': 1610736417}, 'timezone': -18000, 'id': 6096551, 'name': 'Pangnirtung', 'cod': 200}
# Processing Record 11 of Set 2 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.2, 'feels_like': 61.38, 'temp_min': 66.2, 'temp_max': 66.2, 'pressure': 1008, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1610754366, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1610768638, 'sunset': 1610819690}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 12 of Set 2 | pokhara
# {'coord': {'lon': 83.9833, 'lat': 28.2333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 49.42, 'feels_like': 44.64, 'temp_min': 49.42, 'temp_max': 49.42, 'pressure': 1012, 'humidity': 55, 'sea_level': 1012, 'grnd_level': 907}, 'visibility': 10000, 'wind': {'speed': 2.66, 'deg': 9}, 'clouds': {'all': 35}, 'dt': 1610754644, 'sys': {'country': 'NP', 'sunrise': 1610759813, 'sunset': 1610797815}, 'timezone': 20700, 'id': 1282898, 'name': 'Pokhara', 'cod': 200}
# Processing Record 13 of Set 2 | port moresby
# {'coord': {'lon': 147.1797, 'lat': -9.4431}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 84.45, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 340}, 'clouds': {'all': 40}, 'dt': 1610754989, 'sys': {'type': 1, 'id': 42, 'country': 'PG', 'sunrise': 1610740949, 'sunset': 1610786337}, 'timezone': 36000, 'id': 2088122, 'name': 'Port Moresby', 'cod': 200}
# Processing Record 14 of Set 2 | klyavlino
# {'coord': {'lon': 52.0267, 'lat': 54.2649}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 19.56, 'feels_like': 5.13, 'temp_min': 19.56, 'temp_max': 19.56, 'pressure': 1000, 'humidity': 98, 'sea_level': 1000, 'grnd_level': 970}, 'visibility': 135, 'wind': {'speed': 16.62, 'deg': 113}, 'snow': {'1h': 0.25}, 'clouds': {'all': 100}, 'dt': 1610755008, 'sys': {'country': 'RU', 'sunrise': 1610772162, 'sunset': 1610800809}, 'timezone': 14400, 'id': 547383, 'name': 'Klyavlino', 'cod': 200}
# Processing Record 15 of Set 2 | sinnamary
# {'coord': {'lon': -52.95, 'lat': 5.3833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.41, 'feels_like': 79.38, 'temp_min': 77.41, 'temp_max': 77.41, 'pressure': 1011, 'humidity': 88, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 13.44, 'deg': 67}, 'clouds': {'all': 61}, 'dt': 1610754622, 'sys': {'country': 'GF', 'sunrise': 1610703949, 'sunset': 1610746581}, 'timezone': -10800, 'id': 3380290, 'name': 'Sinnamary', 'cod': 200}
# Processing Record 16 of Set 2 | kavaratti
# {'coord': {'lon': 72.642, 'lat': 10.5669}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.68, 'feels_like': 87.35, 'temp_min': 81.68, 'temp_max': 81.68, 'pressure': 1007, 'humidity': 73, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 5.48, 'deg': 83}, 'rain': {'1h': 0.1}, 'clouds': {'all': 81}, 'dt': 1610754660, 'sys': {'country': 'IN', 'sunrise': 1610760701, 'sunset': 1610802372}, 'timezone': 19800, 'id': 1267390, 'name': 'Kavaratti', 'cod': 200}
# Processing Record 17 of Set 2 | xai-xai
# {'coord': {'lon': 33.6442, 'lat': -25.0519}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 77.72, 'feels_like': 82.22, 'temp_min': 77.72, 'temp_max': 77.72, 'pressure': 1005, 'humidity': 85, 'sea_level': 1005, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 8.23, 'deg': 20}, 'clouds': {'all': 41}, 'dt': 1610755009, 'sys': {'country': 'MZ', 'sunrise': 1610766589, 'sunset': 1610815207}, 'timezone': 7200, 'id': 1024552, 'name': 'Xai-Xai', 'cod': 200}
# Processing Record 18 of Set 2 | lasa
# {'coord': {'lon': 10.7002, 'lat': 46.6166}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 18.73, 'feels_like': 9.41, 'temp_min': 14, 'temp_max': 23, 'pressure': 1016, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1610754380, 'sys': {'type': 1, 'id': 6813, 'country': 'IT', 'sunrise': 1610780188, 'sunset': 1610812624}, 'timezone': 3600, 'id': 3175096, 'name': 'Laas', 'cod': 200}
# Processing Record 19 of Set 2 | santiago del estero
# {'coord': {'lon': -64.2615, 'lat': -27.7951}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 88.27, 'feels_like': 94.41, 'temp_min': 88.27, 'temp_max': 88.27, 'pressure': 1000, 'humidity': 55, 'sea_level': 1000, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 73}, 'clouds': {'all': 92}, 'dt': 1610755009, 'sys': {'country': 'AR', 'sunrise': 1610703324, 'sunset': 1610752637}, 'timezone': -10800, 'id': 3835869, 'name': 'Santiago del Estero', 'cod': 200}
# Processing Record 20 of Set 2 | gushikawa
# {'coord': {'lon': 127.8686, 'lat': 26.3544}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.15, 'feels_like': 62.33, 'temp_min': 57.2, 'temp_max': 68, 'pressure': 1017, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 50}, 'clouds': {'all': 1}, 'dt': 1610755009, 'sys': {'type': 1, 'id': 8138, 'country': 'JP', 'sunrise': 1610749063, 'sunset': 1610787495}, 'timezone': 32400, 'id': 1863495, 'name': 'Gushikawa', 'cod': 200}
# Processing Record 21 of Set 2 | cap malheureux
# {'coord': {'lon': 57.6142, 'lat': -19.9842}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.01, 'feels_like': 87.39, 'temp_min': 80.01, 'temp_max': 80.01, 'pressure': 1010, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 104, 'gust': 8.01}, 'clouds': {'all': 1}, 'dt': 1610754650, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1610761396, 'sunset': 1610808892}, 'timezone': 14400, 'id': 934649, 'name': 'Cap Malheureux', 'cod': 200}
# Processing Record 22 of Set 2 | sola
# {'coord': {'lon': 167.55, 'lat': -13.8833}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 82.81, 'feels_like': 85.48, 'temp_min': 82.81, 'temp_max': 82.81, 'pressure': 1008, 'humidity': 77, 'sea_level': 1008, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 13.49, 'deg': 351}, 'rain': {'1h': 2.46}, 'clouds': {'all': 94}, 'dt': 1610755009, 'sys': {'country': 'VU', 'sunrise': 1610735627, 'sunset': 1610781880}, 'timezone': 39600, 'id': 2134814, 'name': 'Sola', 'cod': 200}
# Processing Record 23 of Set 2 | skibbereen
# {'coord': {'lon': -9.2667, 'lat': 51.55}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 50, 'feels_like': 37.78, 'temp_min': 50, 'temp_max': 50, 'pressure': 1013, 'humidity': 100}, 'visibility': 2000, 'wind': {'speed': 21.85, 'deg': 220}, 'clouds': {'all': 75}, 'dt': 1610755010, 'sys': {'type': 1, 'id': 1563, 'country': 'IE', 'sunrise': 1610699759, 'sunset': 1610729798}, 'timezone': 0, 'id': 2961459, 'name': 'Skibbereen', 'cod': 200}
# Processing Record 24 of Set 2 | mount isa
# {'coord': {'lon': 139.5, 'lat': -20.7333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 91.4, 'feels_like': 82.08, 'temp_min': 91.4, 'temp_max': 91.4, 'pressure': 1009, 'humidity': 19}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 160}, 'clouds': {'all': 13}, 'dt': 1610754628, 'sys': {'type': 1, 'id': 9495, 'country': 'AU', 'sunrise': 1610741654, 'sunset': 1610789320}, 'timezone': 36000, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# Processing Record 25 of Set 2 | saldanha
# {'coord': {'lon': 17.9442, 'lat': -33.0117}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 65.28, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1010, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 340}, 'clouds': {'all': 0}, 'dt': 1610754636, 'sys': {'type': 1, 'id': 1943, 'country': 'ZA', 'sunrise': 1610769355, 'sunset': 1610819979}, 'timezone': 7200, 'id': 3361934, 'name': 'Saldanha', 'cod': 200}
# Processing Record 26 of Set 2 | sao filipe
# {'coord': {'lon': -24.4956, 'lat': 14.8961}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.46, 'feels_like': 70.14, 'temp_min': 72.46, 'temp_max': 72.46, 'pressure': 1016, 'humidity': 70, 'sea_level': 1016, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 11.39, 'deg': 49}, 'clouds': {'all': 100}, 'dt': 1610754618, 'sys': {'country': 'CV', 'sunrise': 1610698024, 'sunset': 1610738844}, 'timezone': -3600, 'id': 3374210, 'name': 'São Filipe', 'cod': 200}
# Processing Record 27 of Set 2 | torbay
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}, {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 28.67, 'feels_like': 10.38, 'temp_min': 28, 'temp_max': 30, 'pressure': 1009, 'humidity': 100}, 'visibility': 1207, 'wind': {'speed': 25.32, 'deg': 50, 'gust': 37.98}, 'rain': {'1h': 1.34}, 'clouds': {'all': 90}, 'dt': 1610754667, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1610709265, 'sunset': 1610741160}, 'timezone': -12600, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# Processing Record 28 of Set 2 | victoria
# {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 60.4, 'feels_like': 52.75, 'temp_min': 54, 'temp_max': 63, 'pressure': 1017, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 10.98, 'deg': 65}, 'clouds': {'all': 13}, 'dt': 1610754526, 'sys': {'type': 3, 'id': 2035800, 'country': 'HK', 'sunrise': 1610751904, 'sunset': 1610791236}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# Processing Record 29 of Set 2 | kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 75.6, 'feels_like': 77.56, 'temp_min': 75.6, 'temp_max': 75.6, 'pressure': 1008, 'humidity': 92, 'sea_level': 1008, 'grnd_level': 1006}, 'visibility': 7338, 'wind': {'speed': 12.97, 'deg': 7}, 'rain': {'1h': 3.83}, 'clouds': {'all': 100}, 'dt': 1610754636, 'sys': {'country': 'PG', 'sunrise': 1610740724, 'sunset': 1610784826}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# Processing Record 30 of Set 2 | santa fe
# {'coord': {'lon': -60.7, 'lat': -31.6333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.32, 'feels_like': 78.51, 'temp_min': 72, 'temp_max': 73, 'pressure': 999, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 105, 'gust': 5.01}, 'clouds': {'all': 79}, 'dt': 1610754948, 'sys': {'type': 3, 'id': 2008823, 'country': 'AR', 'sunrise': 1610701975, 'sunset': 1610752276}, 'timezone': -10800, 'id': 3836277, 'name': 'Santa Fe', 'cod': 200}
# Processing Record 31 of Set 2 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 11.03, 'feels_like': 3.97, 'temp_min': 11.03, 'temp_max': 11.03, 'pressure': 1009, 'humidity': 92, 'sea_level': 1009, 'grnd_level': 1005}, 'visibility': 1147, 'wind': {'speed': 2.19, 'deg': 78}, 'clouds': {'all': 99}, 'dt': 1610754629, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 32 of Set 2 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 14.16, 'feels_like': 5.41, 'temp_min': 14.16, 'temp_max': 14.16, 'pressure': 1009, 'humidity': 95, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 1387, 'wind': {'speed': 5.64, 'deg': 94}, 'clouds': {'all': 99}, 'dt': 1610754394, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 33 of Set 2 | nome
# {'coord': {'lon': -165.4064, 'lat': 64.5011}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 23, 'feels_like': 10.9, 'temp_min': 23, 'temp_max': 23, 'pressure': 995, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 320}, 'clouds': {'all': 1}, 'dt': 1610754651, 'sys': {'type': 1, 'id': 7770, 'country': 'US', 'sunrise': 1610742718, 'sunset': 1610761804}, 'timezone': -32400, 'id': 5870133, 'name': 'Nome', 'cod': 200}
# Processing Record 34 of Set 2 | kuche
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 35 of Set 2 | sagae
# {'coord': {'lon': 140.2725, 'lat': 38.3725}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 30.2, 'feels_like': 23.54, 'temp_min': 30.2, 'temp_max': 30.2, 'pressure': 1011, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 100}, 'snow': {'1h': 0.17}, 'clouds': {'all': 75}, 'dt': 1610755011, 'sys': {'type': 1, 'id': 8045, 'country': 'JP', 'sunrise': 1610747656, 'sunset': 1610782946}, 'timezone': 32400, 'id': 2111248, 'name': 'Sagae', 'cod': 200}
# Processing Record 36 of Set 2 | nelson bay
# {'coord': {'lon': 152.15, 'lat': -32.7167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 74.17, 'feels_like': 60.84, 'temp_min': 73.4, 'temp_max': 75, 'pressure': 1009, 'humidity': 21}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1610754616, 'sys': {'type': 1, 'id': 9605, 'country': 'AU', 'sunrise': 1610737166, 'sunset': 1610787734}, 'timezone': 39600, 'id': 2155562, 'name': 'Nelson Bay', 'cod': 200}
# Processing Record 37 of Set 2 | lebu
# ...
# Processing Record 37 of Set 15 | tucurui
# {'coord': {'lon': -49.6725, 'lat': -3.7661}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 75.65, 'feels_like': 82.44, 'temp_min': 75.65, 'temp_max': 75.65, 'pressure': 1009, 'humidity': 90, 'sea_level': 1009, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 3.83, 'deg': 133}, 'rain': {'1h': 0.2}, 'clouds': {'all': 90}, 'dt': 1610754687, 'sys': {'country': 'BR', 'sunrise': 1610702316, 'sunset': 1610746641}, 'timezone': -10800, 'id': 3385935, 'name': 'Tucuruí', 'cod': 200}
# Processing Record 38 of Set 15 | kuytun
# {'coord': {'lon': 101.5036, 'lat': 54.3419}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 3.78, 'feels_like': -8.86, 'temp_min': 3.78, 'temp_max': 3.78, 'pressure': 1036, 'humidity': 93, 'sea_level': 1036, 'grnd_level': 968}, 'visibility': 352, 'wind': {'speed': 11.41, 'deg': 309}, 'snow': {'1h': 0.1}, 'clouds': {'all': 100}, 'dt': 1610754676, 'sys': {'country': 'RU', 'sunrise': 1610760319, 'sunset': 1610788897}, 'timezone': 28800, 'id': 2021093, 'name': 'Kuytun', 'cod': 200}
# Processing Record 39 of Set 15 | qurayyat
# {'coord': {'lon': 37.3428, 'lat': 31.3318}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 42.8, 'feels_like': 38.46, 'temp_min': 42.8, 'temp_max': 42.8, 'pressure': 1016, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 340}, 'clouds': {'all': 0}, 'dt': 1610755086, 'sys': {'type': 1, 'id': 7414, 'country': 'SA', 'sunrise': 1610771383, 'sunset': 1610808638}, 'timezone': 10800, 'id': 108648, 'name': 'Qurayyat', 'cod': 200}
# Processing Record 40 of Set 15 | sompeta
# {'coord': {'lon': 84.6, 'lat': 18.9333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68.41, 'feels_like': 71.29, 'temp_min': 68.41, 'temp_max': 68.41, 'pressure': 1010, 'humidity': 85, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.31, 'deg': 289}, 'clouds': {'all': 10}, 'dt': 1610755086, 'sys': {'country': 'IN', 'sunrise': 1610758649, 'sunset': 1610798683}, 'timezone': 19800, 'id': 1255816, 'name': 'Sompeta', 'cod': 200}
# Processing Record 41 of Set 15 | ust-kuyga
# {'coord': {'lon': 135.6, 'lat': 70.0167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -32.04, 'feels_like': -40.23, 'temp_min': -32.04, 'temp_max': -32.04, 'pressure': 1027, 'humidity': 82, 'sea_level': 1027, 'grnd_level': 1018}, 'visibility': 8514, 'wind': {'speed': 2.01, 'deg': 195}, 'clouds': {'all': 91}, 'dt': 1610755087, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 36000, 'id': 2013921, 'name': 'Ust-Kuyga', 'cod': 200}
# Processing Record 42 of Set 15 | praia da vitoria
# {'coord': {'lon': -27.0667, 'lat': 38.7333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 55.63, 'temp_min': 59, 'temp_max': 59, 'pressure': 1023, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 8.97, 'deg': 231}, 'clouds': {'all': 20}, 'dt': 1610755087, 'sys': {'type': 1, 'id': 6895, 'country': 'PT', 'sunrise': 1610701485, 'sunset': 1610736618}, 'timezone': -3600, 'id': 3372760, 'name': 'Praia da Vitória', 'cod': 200}
# Processing Record 43 of Set 15 | igarape-miri
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 44 of Set 15 | buzmeyin
# {'coord': {'lon': 58.2056, 'lat': 38.0507}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 41, 'feels_like': 34.3, 'temp_min': 41, 'temp_max': 41, 'pressure': 1011, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 180}, 'clouds': {'all': 40}, 'dt': 1610754950, 'sys': {'type': 1, 'id': 8992, 'country': 'TM', 'sunrise': 1610767299, 'sunset': 1610802705}, 'timezone': 18000, 'id': 162099, 'name': 'Abadan', 'cod': 200}
# Processing Record 45 of Set 15 | basco
# {'coord': {'lon': 121.9702, 'lat': 20.4487}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 73.49, 'feels_like': 63.64, 'temp_min': 73.49, 'temp_max': 73.49, 'pressure': 1015, 'humidity': 79, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 28.12, 'deg': 39}, 'clouds': {'all': 25}, 'dt': 1610754642, 'sys': {'country': 'PH', 'sunrise': 1610749836, 'sunset': 1610789554}, 'timezone': 28800, 'id': 1726449, 'name': 'Basco', 'cod': 200}
# Processing Record 46 of Set 15 | xinzhou
# {'coord': {'lon': 112.7333, 'lat': 38.4092}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 17.56, 'feels_like': 11.84, 'temp_min': 17.56, 'temp_max': 17.56, 'pressure': 1035, 'humidity': 84, 'sea_level': 1035, 'grnd_level': 936}, 'visibility': 10000, 'wind': {'speed': 0.34, 'deg': 275}, 'clouds': {'all': 1}, 'dt': 1610755087, 'sys': {'country': 'CN', 'sunrise': 1610754270, 'sunset': 1610789555}, 'timezone': 28800, 'id': 1788450, 'name': 'Xinzhou', 'cod': 200}
# Processing Record 47 of Set 15 | vardo
# {'coord': {'lon': 31.1107, 'lat': 70.3705}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.8, 'feels_like': 25.03, 'temp_min': 33.8, 'temp_max': 33.8, 'pressure': 1012, 'humidity': 93}, 'visibility': 8000, 'wind': {'speed': 9.22, 'deg': 290}, 'snow': {'1h': 0.11}, 'clouds': {'all': 75}, 'dt': 1610754640, 'sys': {'type': 1, 'id': 1682, 'country': 'NO', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 777019, 'name': 'Vardø', 'cod': 200}
# Processing Record 48 of Set 15 | lavrentiya
# {'coord': {'lon': -171, 'lat': 65.5833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 0.99, 'feels_like': -9.74, 'temp_min': 0.99, 'temp_max': 0.99, 'pressure': 1004, 'humidity': 90, 'sea_level': 1004, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 7.76, 'deg': 343}, 'clouds': {'all': 100}, 'dt': 1610754447, 'sys': {'country': 'RU', 'sunrise': 1610831162, 'sunset': 1610848887}, 'timezone': 43200, 'id': 4031637, 'name': 'Lavrentiya', 'cod': 200}
# Processing Record 49 of Set 15 | itoman
# {'coord': {'lon': 127.6694, 'lat': 26.1247}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 63.21, 'feels_like': 58.57, 'temp_min': 57.2, 'temp_max': 68, 'pressure': 1017, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 30}, 'clouds': {'all': 20}, 'dt': 1610755088, 'sys': {'type': 1, 'id': 8137, 'country': 'JP', 'sunrise': 1610749084, 'sunset': 1610787569}, 'timezone': 32400, 'id': 1861280, 'name': 'Itoman', 'cod': 200}
# Processing Record 50 of Set 15 | karaul
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 1 of Set 16 | new richmond
# {'coord': {'lon': -92.5366, 'lat': 45.123}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 33.57, 'feels_like': 24.76, 'temp_min': 33.01, 'temp_max': 33.8, 'pressure': 1006, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 350}, 'clouds': {'all': 90}, 'dt': 1610755088, 'sys': {'type': 1, 'id': 5687, 'country': 'US', 'sunrise': 1610718295, 'sunset': 1610751242}, 'timezone': -21600, 'id': 5264475, 'name': 'New Richmond', 'cod': 200}
# Processing Record 2 of Set 16 | kloulklubed
# {'coord': {'lon': 134.2556, 'lat': 7.0419}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 87.03, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 70}, 'clouds': {'all': 90}, 'dt': 1610754598, 'sys': {'type': 1, 'id': 7901, 'country': 'PW', 'sunrise': 1610745582, 'sunset': 1610787910}, 'timezone': 32400, 'id': 7671223, 'name': 'Kloulklubed', 'cod': 200}
# Processing Record 3 of Set 16 | the valley
# {'coord': {'lon': -63.0578, 'lat': 18.217}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 77.77, 'feels_like': 82.35, 'temp_min': 77, 'temp_max': 78.8, 'pressure': 1015, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 80}, 'clouds': {'all': 20}, 'dt': 1610754643, 'sys': {'type': 1, 'id': 8788, 'country': 'AI', 'sunrise': 1610707612, 'sunset': 1610747771}, 'timezone': -14400, 'id': 3573374, 'name': 'The Valley', 'cod': 200}
# Processing Record 4 of Set 16 | ulan-ude
# {'coord': {'lon': 107.6098, 'lat': 51.8261}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 10.4, 'feels_like': -2.22, 'temp_min': 10.4, 'temp_max': 10.4, 'pressure': 1027, 'humidity': 61}, 'visibility': 9000, 'wind': {'speed': 11.18, 'deg': 310, 'gust': 22.37}, 'snow': {'1h': 0.1}, 'clouds': {'all': 90}, 'dt': 1610755088, 'sys': {'type': 1, 'id': 8896, 'country': 'RU', 'sunrise': 1610758145, 'sunset': 1610788139}, 'timezone': 28800, 'id': 2014407, 'name': 'Ulan-Ude', 'cod': 200}
# Processing Record 5 of Set 16 | martapura
# {'coord': {'lon': 114.85, 'lat': -3.4167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 82.02, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1009, 'humidity': 94}, 'visibility': 9000, 'wind': {'speed': 4.61, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1610755088, 'sys': {'type': 1, 'id': 9360, 'country': 'ID', 'sunrise': 1610749276, 'sunset': 1610793532}, 'timezone': 28800, 'id': 1636022, 'name': 'Martapura', 'cod': 200}
# Processing Record 6 of Set 16 | pucara
# {'coord': {'lon': -71.4606, 'lat': -15.9803}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 50.4, 'temp_min': 53.6, 'temp_max': 53.6, 'pressure': 1024, 'humidity': 87}, 'visibility': 9000, 'wind': {'speed': 5.75, 'deg': 280}, 'rain': {'1h': 0.89}, 'clouds': {'all': 75}, 'dt': 1610755088, 'sys': {'type': 1, 'id': 8696, 'country': 'PE', 'sunrise': 1610706367, 'sunset': 1610753051}, 'timezone': -18000, 'id': 3931656, 'name': 'Pucara', 'cod': 200}
# Processing Record 7 of Set 16 | dukat
# {'coord': {'lon': 155.55, 'lat': 62.55}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -36.9, 'feels_like': -45.47, 'temp_min': -36.9, 'temp_max': -36.9, 'pressure': 1025, 'humidity': 80, 'sea_level': 1025, 'grnd_level': 919}, 'visibility': 6872, 'wind': {'speed': 2.62, 'deg': 290}, 'clouds': {'all': 95}, 'dt': 1610755089, 'sys': {'country': 'RU', 'sunrise': 1610750782, 'sunset': 1610772486}, 'timezone': 39600, 'id': 2125906, 'name': 'Dukat', 'cod': 200}
# Processing Record 8 of Set 16 | sayhat
# {'coord': {'lon': 50.0405, 'lat': 26.4852}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 61.7, 'feels_like': 55.44, 'temp_min': 60.8, 'temp_max': 62.6, 'pressure': 1013, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 280}, 'clouds': {'all': 0}, 'dt': 1610755089, 'sys': {'type': 1, 'id': 7403, 'country': 'SA', 'sunrise': 1610767755, 'sunset': 1610806169}, 'timezone': 10800, 'id': 102318, 'name': 'Sayhāt', 'cod': 200}
# Processing Record 9 of Set 16 | fandriana
# {'coord': {'lon': 47.3833, 'lat': -20.2333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.33, 'feels_like': 67.19, 'temp_min': 64.33, 'temp_max': 64.33, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 863}, 'visibility': 10000, 'wind': {'speed': 2.51, 'deg': 38}, 'clouds': {'all': 100}, 'dt': 1610754966, 'sys': {'country': 'MG', 'sunrise': 1610763826, 'sunset': 1610811374}, 'timezone': 10800, 'id': 1065222, 'name': 'Fandriana', 'cod': 200}
# Processing Record 10 of Set 16 | batagay
# {'coord': {'lon': 134.6333, 'lat': 67.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -33.79, 'feels_like': -41.78, 'temp_min': -33.79, 'temp_max': -33.79, 'pressure': 1028, 'humidity': 82, 'sea_level': 1028, 'grnd_level': 998}, 'visibility': 924, 'wind': {'speed': 1.63, 'deg': 95}, 'clouds': {'all': 100}, 'dt': 1610755089, 'sys': {'country': 'RU', 'sunrise': 1610760158, 'sunset': 1610773152}, 'timezone': 36000, 'id': 2027044, 'name': 'Batagay', 'cod': 200}
# Processing Record 11 of Set 16 | nouadhibou
# {'coord': {'lon': -17.0347, 'lat': 20.931}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 50.5, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1019, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 20}, 'clouds': {'all': 0}, 'dt': 1610754617, 'sys': {'type': 1, 'id': 2444, 'country': 'MR', 'sunrise': 1610696847, 'sunset': 1610736440}, 'timezone': 0, 'id': 2377457, 'name': 'Nouadhibou', 'cod': 200}
# Processing Record 12 of Set 16 | portland
# {'coord': {'lon': -122.6762, 'lat': 45.5234}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 48.27, 'feels_like': 45.66, 'temp_min': 46.99, 'temp_max': 50, 'pressure': 1030, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 40}, 'clouds': {'all': 90}, 'dt': 1610754810, 'sys': {'type': 1, 'id': 5321, 'country': 'US', 'sunrise': 1610725603, 'sunset': 1610758403}, 'timezone': -28800, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# Processing Record 13 of Set 16 | norman
# {'coord': {'lon': -97.4395, 'lat': 35.2226}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.01, 'feels_like': 29.61, 'temp_min': 41, 'temp_max': 43, 'pressure': 1015, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 310, 'gust': 20.71}, 'clouds': {'all': 75}, 'dt': 1610754984, 'sys': {'type': 1, 'id': 5244, 'country': 'US', 'sunrise': 1610717855, 'sunset': 1610754035}, 'timezone': -21600, 'id': 4543762, 'name': 'Norman', 'cod': 200}
# Processing Record 14 of Set 16 | sabha
# {'coord': {'lon': 14.4283, 'lat': 27.0377}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 47.71, 'feels_like': 40.39, 'temp_min': 47.71, 'temp_max': 47.71, 'pressure': 1017, 'humidity': 50, 'sea_level': 1017, 'grnd_level': 967}, 'visibility': 10000, 'wind': {'speed': 6.15, 'deg': 22}, 'clouds': {'all': 0}, 'dt': 1610754966, 'sys': {'country': 'LY', 'sunrise': 1610776365, 'sunset': 1610814657}, 'timezone': 7200, 'id': 2212775, 'name': 'Sabha', 'cod': 200}
# Processing Record 15 of Set 16 | las cruces
# {'coord': {'lon': -106.7783, 'lat': 32.3123}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 53.01, 'feels_like': 45.48, 'temp_min': 53.01, 'temp_max': 53.01, 'pressure': 995, 'humidity': 15}, 'visibility': 10000, 'wind': {'speed': 2.73, 'deg': 300}, 'clouds': {'all': 30}, 'dt': 1610754903, 'sys': {'type': 3, 'id': 2004532, 'country': 'US', 'sunrise': 1610719705, 'sunset': 1610756669}, 'timezone': -25200, 'id': 5475352, 'name': 'Las Cruces', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
df = pd.DataFrame(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(50)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     79.57        66          16
# 1         Kintinku      TZ  -5.8833   35.2333     66.92        93          12
# 2          Bozeman      US  45.6796 -111.0386     35.60        51          90
# 3          Esqueda      MX  30.7167 -109.5833     64.72        25           0
# 4       Georgetown      MY   5.4112  100.3354     78.01        94          20
# 5        Jamestown      US  42.0970  -79.2353     36.00        93          90
# 6            Kapaa      US  22.0752 -159.3190     80.60        74           1
# 7          Ushuaia      AR -54.8000  -68.3000     64.40        48          40
# 8            Nikki      BJ   9.9401    3.2108     70.48        21           0
# 9          Mataura      NZ -46.1927  168.8643     73.00        63          14
# 10           Nadym      RU  65.5333   72.5167      0.36        93         100
# 11       Tuatapere      NZ -46.1333  167.6833     73.00        63          25
# 12          Dikson      RU  73.5069   80.5464    -32.31        79          76
# 13       Cape Town      ZA -33.9258   18.4232     66.99        88          20
# 14          Kodiak      US  57.7900 -152.4072     35.60        87          90
# 15         Sambava      MG -14.2667   50.1667     77.99        87          63
# 16       Ugoofaaru      MV   5.6667   73.0000     80.92        71          54
# 17       Rangapara      IN  26.8167   92.6500     57.52        77          18
# 18         Paamiut      GL  61.9940  -49.6678     23.68        94          81
# 19    Port Augusta      AU -32.5000  137.7667     63.00        51          90
# 20          Lompoc      US  34.6391 -120.4579     69.80        46          66
# 21       Egvekinot      RU  66.3167 -179.1667     -7.69        90         100
# 22    Longyearbyen      SJ  78.2186   15.6401     15.80        92          75
# 23    Puerto Ayora      EC  -0.7393  -90.3518     75.99        91          93
# 24   Mar Del Plata      AR -38.0023  -57.5575     75.20        69           0
# 25         Ahipara      NZ -35.1667  173.1667     72.01        54          43
# 26          Marang      MY   5.2056  103.2059     73.40        94          20
# 27           Oyama      JP  36.3000  139.8000     46.00        93          40
# 28     Port Alfred      ZA -33.5906   26.8910     66.00        90          40
# 29           Bluff      NZ -46.6000  168.3333     73.00        63          89
# 30          Avarua      CK -21.2078 -159.7750     86.00        70          33
# 31     Woensdrecht      NL  51.4163    4.3370     36.00        86          90
# 32        Thompson      CA  55.7435  -97.8558      6.80        78          75
# 33          Yulara      AU -25.2406  130.9889     64.40        72          90
# 34     Spring Hill      US  28.4769  -82.5255     60.80        88          90
# 35           Evans      US  33.5337  -82.1307     51.80        82          40
# 36         Tazmalt      DZ  36.3868    4.3989     41.94        78           6
# 37       Ketchikan      US  55.3422 -131.6461     42.80        87          90
# 38          Albany      US  42.6001  -73.9662     39.00        75         100
# 39  Cabo San Lucas      MX  22.8909 -109.9124     78.01        23           1
# 40     Verkhoyansk      RU  67.5447  133.3850    -32.13        81         100
# 41          Padang      ID  -0.9492  100.3543     75.78        66          56
# 42          Atuona      PF  -9.8000 -139.0333     77.56        77          13
# 43     Grand Gaube      MU -20.0064   57.6608     80.01        84           1
# 44    Punta Arenas      CL -53.1500  -70.9167     55.40        76          40
# 45   Kasongo-Lunda      CD  -6.4667   16.8167     69.94        92         100
# 46        Hermanus      ZA -34.4187   19.2345     59.00        90           1
# 47           Airai      TL  -8.9266  125.4092     64.53       100         100
# 48           Zaria      NG  11.1113    7.7227     64.11        27           0
# 49       Busselton      AU -33.6500  115.3333     66.00        65           0
#
#     Wind Speed Current Description                 Date
# 0         8.19          few clouds  2021-01-15 23:50:11
# 1         1.21       moderate rain  2021-01-15 23:56:42
# 2         1.23     overcast clouds  2021-01-15 23:56:42
# 3         7.16           clear sky  2021-01-15 23:56:42
# 4         5.75          few clouds  2021-01-15 23:50:43
# 5        10.36                snow  2021-01-15 23:50:07
# 6        11.50          light rain  2021-01-15 23:50:14
# 7        10.36    scattered clouds  2021-01-15 23:50:08
# 8         5.10           clear sky  2021-01-15 23:56:43
# 9         8.99          few clouds  2021-01-15 23:48:59
# 10        6.98          light snow  2021-01-15 23:56:43
# 11        8.99    scattered clouds  2021-01-15 23:48:57
# 12        5.17       broken clouds  2021-01-15 23:50:11
# 13        8.05          light rain  2021-01-15 23:46:21
# 14        3.44     overcast clouds  2021-01-15 23:46:06
# 15        7.81          light rain  2021-01-15 23:55:27
# 16       10.98       broken clouds  2021-01-15 23:56:27
# 17        2.51          few clouds  2021-01-15 23:56:44
# 18       13.58       broken clouds  2021-01-15 23:50:38
# 19       16.11     overcast clouds  2021-01-15 23:56:44
# 20       16.11       broken clouds  2021-01-15 23:47:03
# 21       16.53     overcast clouds  2021-01-15 23:51:15
# 22        8.05       broken clouds  2021-01-15 23:50:20
# 23        5.99     overcast clouds  2021-01-15 23:50:06
# 24       11.50           clear sky  2021-01-15 23:50:25
# 25        5.95    scattered clouds  2021-01-15 23:50:27
# 26        2.30          few clouds  2021-01-15 23:56:45
# 27        3.44    scattered clouds  2021-01-15 23:56:45
# 28        3.00    scattered clouds  2021-01-15 23:47:02
# 29        8.99     overcast clouds  2021-01-15 23:50:08
# 30       11.50    scattered clouds  2021-01-15 23:50:09
# 31        3.44     overcast clouds  2021-01-15 23:56:45
# 32        4.61       broken clouds  2021-01-15 23:50:05
# 33        6.91     overcast clouds  2021-01-15 23:50:12
# 34        8.05     overcast clouds  2021-01-15 23:56:46
# 35        3.44    scattered clouds  2021-01-15 23:54:28
# 36        3.29           clear sky  2021-01-15 23:56:46
# 37        4.61          light rain  2021-01-15 23:46:11
# 38        8.48     overcast clouds  2021-01-15 23:49:52
# 39       11.50           clear sky  2021-01-15 23:46:05
# 40        1.28     overcast clouds  2021-01-15 23:56:46
# 41        3.80       broken clouds  2021-01-15 23:50:41
# 42       12.35          light rain  2021-01-15 23:49:46
# 43        5.99           clear sky  2021-01-15 23:56:47
# 44       12.66    scattered clouds  2021-01-15 23:49:50
# 45        0.72     overcast clouds  2021-01-15 23:56:47
# 46        9.62           clear sky  2021-01-15 23:49:49
# 47        1.16          light rain  2021-01-15 23:50:16
# 48        7.87           clear sky  2021-01-15 23:56:47
# 49        5.99           clear sky  2021-01-15 23:48:59

# %%
city_data_df.drop('Date', axis=1, inplace=True)

# %%
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     79.57        66          16
# 1      Kintinku      TZ  -5.8833   35.2333     66.92        93          12
# 2       Bozeman      US  45.6796 -111.0386     35.60        51          90
# 3       Esqueda      MX  30.7167 -109.5833     64.72        25           0
# 4    Georgetown      MY   5.4112  100.3354     78.01        94          20
# ..          ...     ...      ...       ...       ...       ...         ...
# 699  Nouadhibou      MR  20.9310  -17.0347     62.60        59           0
# 700    Portland      US  45.5234 -122.6762     50.00        87          90
# 701      Norman      US  35.2226  -97.4395     43.00        36          75
# 702       Sabha      LY  27.0377   14.4283     47.71        50           0
# 703  Las Cruces      US  32.3123 -106.7783     53.01        15          30
#
#      Wind Speed Current Description
# 0          8.19          few clouds
# 1          1.21       moderate rain
# 2          1.23     overcast clouds
# 3          7.16           clear sky
# 4          5.75          few clouds
# ..          ...                 ...
# 699       20.71           clear sky
# 700        2.39     overcast clouds
# 701       12.66       broken clouds
# 702        6.15           clear sky
# 703        2.73    scattered clouds
#
# [704 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
